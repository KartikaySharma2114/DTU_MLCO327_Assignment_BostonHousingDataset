# %%
# !pip install matplotlib
# !pip install scikit-learn
# !pip install seaborn
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import metrics
import pandas as pd  
import seaborn as sns 
from scipy import stats

# !matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from scikit-learn) (3.5.0)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kkysh\downloads\mealpy\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kkysh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Traceback (most recent call last):
#   File "C:\Users\kkysh\anaconda3\Scripts\matplotlib-script.py", line 10, in <module>
#     sys.exit(plotting._matplotlib())
#              ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pandas.plotting' has no attribute '_matplotlib'

# %%
file_path = r'C:\Users\kkysh\Downloads\boston-housing\train.csv'

# Load the dataset
boston = pd.read_csv(file_path)

# %%
print(boston.keys())
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
print(boston.head())
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
print(boston[boston.chas==0])
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [313 rows x 15 columns]

# %%
boston['House_price'] = boston['medv']

# %%
boston.sort_values('House_price',ascending=False)
# Out:
#       ID      crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 110  164   1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# 130  187   0.05602   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193
# 113  167   2.01019   0.0  19.58     0  0.6050  7.929   96.2  2.0459    5  403
# 142  205   0.02009  95.0   2.68     0  0.4161  8.034   31.9  5.1180    4  224
# 109  162   1.46336   0.0  19.58     0  0.6050  7.489   90.8  1.9709    5  403
# ..   ...       ...   ...    ...   ...     ...    ...    ...     ...  ...  ...
# 263  402  14.23620   0.0  18.10     0  0.6930  6.343  100.0  1.5741   24  666
# 269  416  18.08460   0.0  18.10     0  0.6790  6.434  100.0  1.8347   24  666
# 268  415  45.74610   0.0  18.10     0  0.6930  4.519  100.0  1.6582   24  666
# 262  401  25.04610   0.0  18.10     0  0.6930  5.987  100.0  1.5888   24  666
# 261  399  38.35180   0.0  18.10     0  0.6930  5.453  100.0  1.4896   24  666
#
#      ptratio   black  lstat  medv  House_price
# 110     14.7  388.45   3.32  50.0         50.0
# 130     17.8  392.63   4.45  50.0         50.0
# 113     14.7  369.30   3.70  50.0         50.0
# 142     14.7  390.55   2.88  50.0         50.0
# 109     14.7  374.43   1.73  50.0         50.0
# ..       ...     ...    ...   ...          ...
# 263     20.2  396.90  20.32   7.2          7.2
# 269     20.2   27.25  29.05   7.2          7.2
# 268     20.2   88.27  36.98   7.0          7.0
# 262     20.2  396.90  26.77   5.6          5.6
# 261     20.2  396.90  30.59   5.0          5.0
#
# [333 rows x 16 columns]

# %%
boston=boston[boston.House_price!=50]

# %%
boston.isnull().sum()
# Out:
# ID             0
# crim           0
# zn             0
# indus          0
# chas           0
# nox            0
# rm             0
# age            0
# dis            0
# rad            0
# tax            0
# ptratio        0
# black          0
# lstat          0
# medv           0
# House_price    0
# dtype: int64

# %%
boston[boston.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, black, lstat, medv, House_price]
# Index: []

# %%
boston.shape
# Out:
# (322, 16)

# %%
boston.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv', 'House_price'],
#       dtype='object')

# %%
boston.dtypes
# Out:
# ID               int64
# crim           float64
# zn             float64
# indus          float64
# chas             int64
# nox            float64
# rm             float64
# age            float64
# dis            float64
# rad              int64
# tax              int64
# ptratio        float64
# black          float64
# lstat          float64
# medv           float64
# House_price    float64
# dtype: object

# %%
boston.nunique()
# Out:
# ID             322
# crim           322
# zn              25
# indus           67
# chas             2
# nox             77
# rm             298
# age            255
# dis            286
# rad              9
# tax             58
# ptratio         41
# black          227
# lstat          301
# medv           191
# House_price    191
# dtype: int64

# %%
correlation_matrix = boston.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
z = np.abs(stats.zscore(boston))
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 35,  36,  37,  43,  44,  69,  96,  97, 104, 105, 108, 134, 135,
#        136, 137, 137, 137, 140, 141, 144, 145, 146, 148, 153, 154, 154,
#        154, 155, 157, 167, 170, 170, 170, 178, 179, 182, 182, 182, 183,
#        185, 187, 188, 223, 224, 226, 227, 228, 229, 233, 235, 236, 237,
#        237, 250, 256, 257, 257, 257, 258, 259, 260, 260, 261, 262, 263,
#        264, 264, 266, 267, 271, 278, 284, 285, 294], dtype=int64), array([ 2,  2,  2,  2,  2, 12, 13,  4,  4, 12,  4,  2,  2,  2,  2, 14, 15,
#         4,  4,  4,  4,  4,  6,  6,  6, 14, 15,  4,  4,  6,  6, 14, 15,  4,
#         4,  4, 14, 15,  2,  2,  2,  2,  2,  2,  8,  4,  4,  4,  6,  6, 13,
#         6, 13,  1,  1,  1, 12, 13, 12,  1,  1, 12, 12, 12, 12,  1, 12, 12,
#        12, 12, 12, 12, 12, 12], dtype=int64))

# %%
boston.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   250.580745    3.367846   10.479814   11.233043    0.049689    0.556969
# std    149.453255    7.451904   22.063002    6.968318    0.217641    0.115737
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    120.250000    0.079882    0.000000    5.130000    0.000000    0.453000
# 50%    244.500000    0.251680    0.000000    9.690000    0.000000    0.538000
# 75%    383.750000    3.506773   12.500000   18.100000    0.000000    0.624000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean     6.230025   67.882298    3.749375    9.568323  408.369565   18.493168
# std      0.657170   28.119301    1.982530    8.705818  170.118769    2.120310
# min      3.561000    6.000000    1.137000    1.000000  188.000000   12.600000
# 25%      5.881000   45.175000    2.167575    4.000000  279.250000   17.400000
# 50%      6.180500   76.500000    3.100900    5.000000  330.000000   19.050000
# 75%      6.551250   93.475000    5.117675   24.000000  666.000000   20.200000
# max      8.398000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv  House_price
# count  322.000000  322.000000  322.000000   322.000000
# mean   358.781770   12.792360   21.838509    21.838509
# std     87.937301    7.010137    7.794687     7.794687
# min      3.500000    1.980000    5.000000     5.000000
# 25%    377.070000    7.432500   17.225000    17.225000
# 50%    392.265000   11.415000   21.300000    21.300000
# 75%    396.322500   16.702500   24.600000    24.600000
# max    396.900000   37.970000   48.800000    48.800000

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['House_price'], bins=30)
plt.show()
# Out:
# C:\Users\kkysh\AppData\Local\Temp\ipykernel_22236\1163262099.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(boston['House_price'], bins=30)

# %%
correlation_matrix = boston.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
X = pd.DataFrame(np.c_[boston['lstat'], boston['rm'],boston['ptratio'],boston['indus']], columns = ['LSTAT','RM','PTRATIO','INDUS'])
Y = boston['House_price']
print(X)
print(Y)
# Out:
#      LSTAT     RM  PTRATIO  INDUS
# 0     4.98  6.575     15.3   2.31
# 1     9.14  6.421     17.8   7.07
# 2     2.94  6.998     18.7   2.18
# 3     5.33  7.147     18.7   2.18
# 4    12.43  6.012     15.2   7.87
# ..     ...    ...      ...    ...
# 317  15.10  5.569     19.2   9.69
# 318   9.67  6.593     21.0  11.93
# 319   9.08  6.120     21.0  11.93
# 320   5.64  6.976     21.0  11.93
# 321   7.88  6.030     21.0  11.93
#
# [322 rows x 4 columns]
# 0      24.0
# 1      21.6
# 2      33.4
# 3      36.2
# 4      22.9
#        ...
# 328    17.5
# 329    22.4
# 330    20.6
# 331    23.9
# 332    11.9
# Name: House_price, Length: 322, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (225, 4)
# (97, 4)
# (225,)
# (97,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()

# %%
from sklearn.model_selection import KFold, cross_val_score
import math

# Assuming X_train and y_train are your training features and target
kfold = KFold(n_splits=10, shuffle=True, random_state=6)
cv = cross_val_score(lin_model, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error')
sqrt_cv = [math.sqrt(abs(i)) for i in cv]

print("Root Mean Square Error (RMSE) scores:", sqrt_cv)
# Out:
# Root Mean Square Error (RMSE) scores: [3.7424154199446726, 4.175922504308726, 4.388338032781543, 5.052094163071101, 4.032757940858609, 4.3606595308858855, 4.15491457812285, 3.1812392927500857, 4.625364955385882, 5.20395404351089]

# %%
print("R-squared Value\n")
scoring = 'r2'
kfold = model_selection.KFold(n_splits=10, random_state=6,shuffle=True)
cv = model_selection.cross_val_score(lin_model, X_train, y_train, cv=kfold, scoring=scoring)
print("{} ({})".format( cv.mean(), cv.std()))
print('Result from each iteration of cross validation:', cv, '\n')
# Out:
# R-squared Value
#
# 0.6337800475104173 (0.16282970387327994)
# Result from each iteration of cross validation: [0.61828004 0.6566696  0.69076401 0.63742938 0.82063747 0.35336884
#  0.67996906 0.83525819 0.32250555 0.72291833]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Fit the model and make predictions
model = lin_model
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Calculate metrics
rmse_score = np.sqrt(mean_squared_error(y_test, y_pred))
rsquared_score = r2_score(y_test, y_pred)

print('RMSE score:', rmse_score)
print('R2 score:', rsquared_score)
print('\nScatter plot of y_test against y_pred:')

# Create scatter plot with regression line
sns.regplot(x=y_test, y=y_pred)

# Show the plot
plt.show()
# Out:
# RMSE score: 3.9612501982982935
# R2 score: 0.7270353025992764
#
# Scatter plot of y_test against y_pred:
